# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202511_BD53/blob/main/lab_python/python06_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # list

# %% [markdown]
# *   `list`: 여러 개의 값들을 하나의 변수에 저장하기 위한 데이터 타입.
# *   아이템(item). 원소(element): 리스트에 저장된 각각의 값.
# *   인덱스(index): 리스트에 아이템들이 저장된 위치를 표시하는 정수.
#     *   리스트의 인덱스는 **0**부터 시작.
#     *   리스트의 마지막 인덱스는 (아이템 개수 - 1)
#     *   리스트의 끝에서부터 역순으로 인덱스를 매길 때는 *음수 인덱스*를 사용할 수 있음.
# *   리스트는 아이템들을 추가, 변경, 삭제할 수 있음.
#     *   `tuple`과 다른 점.

# %%
# 숫자들을 저장하는 list
numbers = [1, 2, 10, 20, -1, -100]
print(type(numbers))
print(numbers)
# Out:
# <class 'list'>
# [1, 2, 10, 20, -1, -100]

# %%
# 파이썬의 리스트는 여러가지 타입의 값들을 하나의 변수에 저장할 수 있음.
values = [1, 2, '안녕', '파이썬', 3.141592, True, [1, 2, 3]]
print(type(values))
print(values)
# Out:
# <class 'list'>
# [1, 2, '안녕', '파이썬', 3.141592, True, [1, 2, 3]]

# %% [markdown]
# # Indexing
#
# 인덱스를 사용해서 리스트의 아이템을 사용하는 방법.
# `list_name[index]`

# %%
numbers = [1, -2, -3, 4, 5, 100]
numbers
# Out:
# [1, -2, -3, 4, 5, 100]

# %%
numbers[0]  # 리스트 numbers의 인덱스 0 위치(첫번째)의 원소
# Out:
# 1

# %%
numbers[1]  # 인덱스 1번 위치(두번째)의 원소.
# Out:
# -2

# %%
numbers[5]
# Out:
# 100

# %%
numbers[-1]  # 끝에서 첫번째 아이템. 마지막 아이템.
# Out:
# 100

# %%
numbers[-2]  # 끝에서 두번째 아이템.
# Out:
# 5

# %%
print(numbers[-1])
print(numbers[-2])
# Out:
# 100
# 5
